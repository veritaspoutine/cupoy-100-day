# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()
# Out:
# [-1.78273371e+01  3.48142651e+00 -7.83041973e-02  1.54631248e+00
#  -2.33805864e+01  4.33858657e+01  2.26261989e+01  1.96603171e+01
#   1.30530544e+01  4.12825639e+01  2.11904098e+01  4.10433493e+01
#   4.79337975e+01  5.38419466e+01  3.65717875e+01  5.33225521e+01
#   3.28153024e+01  5.91916187e+01  4.19120040e+01  5.01221923e+01
#   4.93230974e+01  5.40387753e+01  6.21882804e+01  9.16759278e+01
#   8.02585704e+01  9.90990380e+01  8.17862926e+01  7.59738165e+01
#   4.83185111e+01  8.01339584e+01  1.05604846e+02  8.22339431e+01
#   9.32056776e+01  1.22126023e+02  9.95259889e+01  1.01156745e+02
#   1.41043930e+02  1.26167711e+02  1.02899357e+02  1.11757267e+02
#   1.16514042e+02  1.13759595e+02  1.33043999e+02  7.99117344e+01
#   1.08680800e+02  1.19707554e+02  1.45477112e+02  1.35231532e+02
#   1.41603987e+02  1.49951999e+02  1.47357674e+02  2.12951885e+02
#   1.63104623e+02  1.71401357e+02  1.75432674e+02  1.58890770e+02
# ...

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 188.592
# The Mean absolute error is 11.194

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 競賽: Rainforest Connection Species Audio Detection
# 追蹤雨林的棲息地分佈狀況，可以推斷氣候變遷速度與劇烈性，以及與林開發的速度。但由於雨林本身高生物多樣性的緣故，傳統用肉眼觀察生物的方法成本高且有空間限制，利用聲音來來追蹤生物多樣性可以解決以上問題。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 這個競賽是由非營利組織 Rainforest Connection (RFCx) 所提供。資料收集方式是該組織在全世界雨林中架設即時生物監控系統收集聲音。
#
# 3. 蒐集而來的資料型態為何
# 這個比賽提供:
# * 非結構化資料 flac 音訊檔
# * 結構化資料 csv 檔紀錄訓練音訊內生物出現時間點
#
#
# 4. 這組資料想解決的問題如何評估
# 這個比賽的目標是如何在吵雜的訓練音檔內，辨識出雨林內的鳥類和青蛙物種，然後建置一個針對鳥類和青蛙物種的聲音辨識的監控系統。這個問題的本質是一個分類問題。若成功的化，將會是一個即時生態聲音監控系統。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ### 我們先來定義"提升業績"
#
# 假設:
# * 業績定義: 車隊駕駛每季平均每天載客次數
# * 營運範圍: 北北基宜桃
# * 叫車方式: App/電話/路邊隨招
# * 付款方式: 信用卡，第三方支付，悠遊卡，現金
# * 線上市場: 透過 App 或是電話叫車
# * 離線市場: 路邊隨招
#
# 假設問題:
# WHAT: 增強線上叫車流程體驗，提升線上市場市佔率，進而提升業績(駕駛平均每天載客次數)
# WHY: 離線市場痿縮，乘客叫車習慣隨路邊隨招逐漸改為線上叫車
# HOW: 縮短開啟 App 到確認叫車中間時間，增強 App 使用體驗。
#
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料收集方式:
# * App 後端/DB:
#     - 服務面向: 車號/駕駛編號, 每天載客趟數, 每趟上下車地點, 上下車時間, 每趟時段， 每趟距離， 每趟車資, 每趟付款方式， 叫車取消次數， 乘客性別, 乘客候車時間，年齡層範圍
#     - 系統面向: App 開啟到叫車確認時間, App SLA 等級, 各 os 下載次數, 用戶每周使用次數
# * 電話叫車後端/DB:
#     - 服務面向: 同 App
#     - 系統面向: 真人叫車等待時間, 系統語音叫車等待時間
# * 路邊隨招: 車內跳表設備收集車號/駕駛編號, 每天載客趟數, 每趟上下車地點, 每趟時段, 每趟車資，付款方式。每趟即時回傳資料
#
# 路邊隨招的方式可能因為跳表機故障關係，損失資料收集機會。另外乘客性別和年齡層需要司機手動輸入，這裏有人爲失誤的問題存在導致資料失真。
#
#
# 3. 蒐集而來的資料型態為何
# 基本上資料都是以 csv 格式收集後匯入 RDB。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 我們在這裏要做的事情是增加線上叫車的市佔率。眾多的線上叫車平臺中，如何吸引使用者使用我們的平臺叫車，完全取決於線上叫車體驗，其中一個體驗是從開啟 App 到確認叫車這個時間過程, 我們假設這個時間叫做 time to confirm (ttc). 我們大膽假設 ttc 這個變數越小, app 市佔率越高。
#
# 這個問題的本質是個回歸問題， 我們可以透過回歸模型找出市佔率。先前假設 ttc 影響 app 市佔率非常高，但是我們也可用其他變數例如用戶年齡層，上下車地點等等來觀察與市佔率的影響程度高低。
